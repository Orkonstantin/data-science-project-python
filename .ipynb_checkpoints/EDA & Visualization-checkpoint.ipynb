# %% [markdown]
# ## EDA

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
himovies_df=pd.read_csv('data\Clean_df.csv')
himovies_df
# Out:
#                     movie_name  release_year  imdb_grades  \
# 0          Operation Mincemeat          2022          6.9
# 1                       Memory          2022          5.6
# 2                 Stanleyville          2021          5.6
# 3                  Scarborough          2021          7.1
# 4      It's Hard But It's Fair          2022          5.6
# ...                        ...           ...          ...
# 29372             The Shooting          1966          6.5
# 29373          The Con Artists          2014          6.5
# 29374         And There Were 4          2018          4.6
# 29375        From Time to Time          2009          6.7
# 29376          Sanshiro Sugata          1943          6.7
#
#                               genres  \
# 0                  Drama,History,War
# 1      Crime,Thriller,Action,Mystery
# 2                             Comedy
# 3                              Drama
# 4                              Drama
# ...                              ...
# 29372                        Western
# 29373          Thriller,Action,Crime
# 29374           Action,Drama,Fantasy
# 29375        Adventure,Fantasy,Drama
# 29376                          Drama
#
#                                                    casts  duration in min  \
# 0      MarkBonnar,HattieMorahan,JohnnyFlynn,MatthewMa...              128
# 1      LiamNeeson,TajAtwal,MonicaBellucci,HaroldTorre...              114
# 2      JulianRichings,GeorgeTchortov,ChristianSerriti...               88
# 3      EssenceFox,ElliePosadas,LiamDiaz,CherishViolet...              136
# 4      Osaze'Agod'Niamke,Derrick'Deuce'Keys,Moonrise'...               74
# ...                                                  ...              ...
# 29372  WarrenOates,WillHutchins,MilliePerkins,JackNic...               78
# 29373  KimWoo-bin,LeeHyun-woo,KimYeong-cheol,JoYoon-h...              116
# 29374  ShadnerIfrene,NathanielRyanJ,MysonneLinen,BekM...               83
# 29375  MaggieSmith,DominicWest,TimothySpall,Alexander...               95
# 29376  DenjirôÔkôchi,SusumuFujita,YukikoTodoroki,Taka...               80
#
#                      country  \
# 0              UnitedKingdom
# 1      UnitedStatesofAmerica
# 2                     Canada
# 3                     Canada
# 4      UnitedStatesofAmerica
# ...                      ...
# 29372  UnitedStatesofAmerica
# 29373             SouthKorea
# 29374  UnitedStatesofAmerica
# 29375          UnitedKingdom
# 29376                  Japan
#
#                                               production
# 0      ArcheryPictures,AFilmLocationCompany,CohenMedi...
# 1      BlackBearPictures,SavilleProductions,OpenRoadF...
# 2                                ScythiaFilms,Anthropoid
# 3                                   CompyFilms,levelFILM
# 4                    MemphvilleManagementandDistribution
# ...                                                  ...
# 29372                 ProteusFilms,SantaClaraProductions
# 29373                                 LotteEntertainment
# 29374                                                XXX
# 29375                      LionheadStudios,EalingStudios
# 29376             TohoFilm(Eiga)Co.Ltd.,TohoCompany,Ltd.
#
# [29377 rows x 8 columns]

# %%
m=himovies_df["country"]
movies=m.value_counts().reset_index()[0:10]
plt.figure(figsize=(12,6))
plt.title("TOP TEN COUNTRIES WITH HIGHEST NUMBER OF MOVIES",fontsize=25)
ax=sns.barplot(x=movies["index"],y=movies["country"])
plt.xticks(rotation =45)
for i in ax.patches:
    ax.text(i.get_x()+.25,i.get_height()+2.3,str(int((i.get_height()))),
            rotation=0,fontsize=15,color='black')

# %% [markdown]
# ### America is the country that produces the most films, by a large margin from the other countries.
# ### In the other countries, we see that the number of movies homogeneous.

# %%
fig = plt.figure(figsize=(25, 5))
fig1 = fig.add_subplot(1,3,1)

fig1.hist(himovies_df.imdb_grades,color="skyblue",edgecolor='black')
fig1.set_title('IMDB Scores Distribution')
fig1.set_xlabel("imdb_grades")
fig1.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### This histogram shows us that most of the films’ IMDB scores lie between around 5.5–7.5

# %%
y=himovies_df.groupby("genres")['genres'].count().nlargest(20)
x = y.index
 
plt.figure(figsize=(10,10))
ax = sns.barplot(x= y, y = x)
ax.set(xlabel = 'Count')
ax.set(ylabel = '')

plt.show()

# %% [markdown]
# ### From this, we can see that most of our data is about the drama genre

# %% [markdown]
# ## We decided to split the genres column to get a better perspective on each film

# %%
for idx,row in enumerate (himovies_df['genres']):
    himovies_df['genres'].at[idx] = row.split(",")[0]        

himovies_df = himovies_df[himovies_df["genres"].str.contains("TVMovie") == False]

# %%
genre_filter=himovies_df['genres'].value_counts().loc[lambda x: x>300].to_frame()
genre_filter
# Out:
#                 genres
# Drama             6951
# Comedy            4973
# Action            2952
# Horror            2709
# Thriller          2131
# Romance           1386
# Documentary       1349
# Crime             1175
# Adventure         1052
# ScienceFiction     718
# Animation          655
# Family             639
# Fantasy            525
# Mystery            501
# Music              328

# %% [markdown]
# ### Since there have been many movies with different genres over the years, we’ll only analyze a few of the common genres from 2010 onwards

# %%
temp_df = himovies_df[himovies_df["genres"].str.contains("Drama|Comedy|Action|Horror|Thriller|Romance|Documentary|Adventure" ) == True]
temp_df = temp_df[temp_df['release_year']>=2010]

# %%
# plotting the genre_filter in a line plot along with the years 
g=sns.lineplot(data=temp_df, x=temp_df["release_year"], y=temp_df['imdb_grades'], hue=temp_df["genres"], ci=None,linewidth = 2, palette="Set2")
g.legend(loc='upper right', bbox_to_anchor=(1.35, 1), prop={'size': 15})
fig = plt.gcf()
fig.set_size_inches(12, 8)

# %%
#storing the top 3 genres since 2010 with highest IMDB scores in a list 
list_of_genre= ["Documentary", "Drama", "Romance"] 

genre_list_count=[]
for i in range(0,3):
    genre_count=len(temp_df[temp_df['genres'] == list_of_genre[i]])

    genre_list_count.append(genre_count) # appending the total count of each genre in the list

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
colorss = ['#FEA82F','#1BE7FF','#A599B5']
ax.pie(genre_list_count, labels = list_of_genre,autopct='%1.2f%%', colors=colorss, wedgeprops = {'linewidth': 3}, radius=1.2, textprops = {"fontsize":15})
plt.show()

# %% [markdown]
# ### In the lineplot graph, we can see that the Documentary genre leads in its IMDB score over the years since 2010, followed by the category of drama and finally the category of romance.
#
# ### The Pie graph shows the percentage amount of movies in the top genres above.

# %% [markdown]
# # Correlation

# %%
ct = pd.crosstab(himovies_df['genres'],(himovies_df['imdb_grades'] > 7) ,normalize="index")#.sort_values(by = 'imdb_grades', ascending=False)

ax = ct.plot(kind="bar", figsize=(18,6))
ax.legend(["Bad movie", "Good movie"],fancybox=True, framealpha=1, shadow=True, borderpad=1)

for container in ax.containers:
    ax.bar_label(container)
plt.title("Movies graded above 7.0 by genres", fontsize = 20)
plt.ylabel("Relative frequency")
# Out:
# Text(0, 0.5, 'Relative frequency')

# %%
corr = himovies_df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style type="text/css">
# #T_02879_row0_col0, #T_02879_row1_col1, #T_02879_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_02879_row0_col1, #T_02879_row0_col2, #T_02879_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_02879_row1_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_02879_row2_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_02879_row2_col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# </style>
# <table id="T_02879_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >release_year</th>
#       <th class="col_heading level0 col1" >imdb_grades</th>
#       <th class="col_heading level0 col2" >duration in min</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02879_level0_row0" class="row_heading level0 row0" >release_year</th>
#       <td id="T_02879_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_02879_row0_col1" class="data row0 col1" >-0.30</td>
#       <td id="T_02879_row0_col2" class="data row0 col2" >-0.09</td>
#     </tr>
#     <tr>
#       <th id="T_02879_level0_row1" class="row_heading level0 row1" >imdb_grades</th>
#       <td id="T_02879_row1_col0" class="data row1 col0" >-0.30</td>
#       <td id="T_02879_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_02879_row1_col2" class="data row1 col2" >0.35</td>
#     </tr>
#     <tr>
#       <th id="T_02879_level0_row2" class="row_heading level0 row2" >duration in min</th>
#       <td id="T_02879_row2_col0" class="data row2 col0" >-0.09</td>
#       <td id="T_02879_row2_col1" class="data row2 col1" >0.35</td>
#       <td id="T_02879_row2_col2" class="data row2 col2" >1.00</td>
#     </tr>
#   </tbody>
# </table>
